# %% [markdown]
# # Preguntas
#
# - ¿Cuantas personas compran productos?
# - ¿A que edad empiezan a comprar?
# - ¿Cual es el salario promedio de las personas que si compran?
# - ¿Que sexo compra más en la tienda?
# - ¿Hay más gente que compra o solo ve los productos?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
data = pd.read_csv("Datos/Social_Network_Ads.csv").drop(['User ID'], axis=1)
data
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %%
data.rename(columns={'EstimatedSalary':'Estimated Salary'}, inplace=True)
data
# Out:
#      Gender  Age  Estimated Salary  Purchased
# 0      Male   19             19000          0
# 1      Male   35             20000          0
# 2    Female   26             43000          0
# 3    Female   27             57000          0
# 4      Male   19             76000          0
# ..      ...  ...               ...        ...
# 395  Female   46             41000          1
# 396    Male   51             23000          1
# 397  Female   50             20000          1
# 398    Male   36             33000          0
# 399  Female   49             36000          1
#
# [400 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# Gender              0
# Age                 0
# Estimated Salary    0
# Purchased           0
# dtype: int64

# %%
data.set_index("Age")
# Out:
#      Gender  Estimated Salary  Purchased
# Age
# 19     Male             19000          0
# 35     Male             20000          0
# 26   Female             43000          0
# 27   Female             57000          0
# 19     Male             76000          0
# ..      ...               ...        ...
# 46   Female             41000          1
# 51     Male             23000          1
# 50   Female             20000          1
# 36     Male             33000          0
# 49   Female             36000          1
#
# [400 rows x 3 columns]

# %%
data.dtypes
# Out:
# Gender              object
# Age                  int64
# Estimated Salary     int64
# Purchased            int64
# dtype: object

# %%
data_uwu = data.sort_values("Age").set_index("Age")
data_uwu
# Out:
#      Gender  Estimated Salary  Purchased
# Age
# 18     Male             52000          0
# 18   Female             86000          0
# 18   Female             44000          0
# 18     Male             82000          0
# 18   Female             68000          0
# ..      ...               ...        ...
# 60     Male             42000          1
# 60   Female             46000          1
# 60     Male            102000          1
# 60     Male             34000          1
# 60     Male             83000          1
#
# [400 rows x 3 columns]

# %%
purchaser = data_uwu[data_uwu['Purchased']!=0].sort_values("Age")
purchaser
# Out:
#      Gender  Age  Estimated Salary  Purchased
# 146  Female   27             96000          1
# 31   Female   27            137000          1
# 97     Male   28            123000          1
# 168    Male   29            148000          1
# 137    Male   30            107000          1
# ..      ...  ...               ...        ...
# 272    Male   60             42000          1
# 393    Male   60             42000          1
# 370  Female   60             46000          1
# 223    Male   60            102000          1
# 371    Male   60             83000          1
#
# [143 rows x 4 columns]

# %%
purchaser.count()
# Out:
# Gender              143
# Age                 143
# Estimated Salary    143
# Purchased           143
# dtype: int64

# %%
purchaser.describe()
# Out:
#               Age  Estimated Salary  Purchased
# count  143.000000        143.000000      143.0
# mean    46.391608      86272.727273        1.0
# std      8.612172      42064.200064        0.0
# min     27.000000      20000.000000        1.0
# 25%     39.500000      41000.000000        1.0
# 50%     47.000000      90000.000000        1.0
# 75%     53.000000     122500.000000        1.0
# max     60.000000     150000.000000        1.0

# %%
purchaser.count()
# Out:
# Gender              143
# Age                 143
# Estimated Salary    143
# Purchased           143
# dtype: int64

# %% [markdown]
# ### 1ra Pregunta

# %%
data['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Purchased'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Purchased'>

# %%
labels = 'No realizo ninguna compra', 'Si realizó una compra'
compradores = data['Purchased'].value_counts()
explode = (0, 0.1)

plt.pie(compradores, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbdb39dc3d0>,
# ...
#  [Text(-0.9916006537889979, -0.476159787681858, 'No realizo ninguna compra'),
#   Text(1.0817462164039533, 0.519446939827093, 'Si realizó una compra')],
#  [Text(-0.5408730838849078, -0.2597235205537407, '64.2%'),
#   Text(0.6310186262356394, 0.30301071489913756, '35.7%')])
